# %%
from analytics_v2 import parse_LI, plot_LI
import matplotlib.pyplot as plt

# %% [markdown]
# ## Getting Data

# %%
path = "data_basis/"
data = parse_LI(path)

data
# Out:
# {'232': {'LI num': [13, 13, 13, 13], 'dimension': [2, 3, 4, 5]},
#  '432': {'LI num': [382, 1457, 1457, 1457], 'dimension': [2, 3, 4, 5]},
#  '332': {'LI num': [84, 190, 190, 190], 'dimension': [2, 3, 4, 5]},
#  '322': {'LI num': [35, 46, 46, 46], 'dimension': [2, 3, 4, 5]},
#  '222': {'LI num': [9, 9, 9, 9], 'dimension': [2, 3, 4, 5]},
#  '233': {'LI num': [206, 253, 253], 'dimension': [3, 4, 5]},
#  '422': {'LI num': [102, 161, 161, 161], 'dimension': [2, 3, 4, 5]},
#  '622': {'LI num': [492, 937, 937, 937], 'dimension': [2, 3, 4, 5]},
#  '522': {'LI num': [241, 426, 426, 426], 'dimension': [2, 3, 4, 5]}}

# %% [markdown]
# ## Dimension Classification

# %%
plot_LI(path)

# %%
plot_LI(path, show_useful = True)

# %% [markdown]
# # Classification in the M-2-2 Scenario

# %%
Ratio = []
M = []

for k in data.keys():
    if k[1:] == '22':
        print(k, data[k])
        M.append(int(k[0]))
        Ratio.append(data[k]['LI num'][1]/data[k]['LI num'][0])
        
Ratio = [r for _,r in sorted(zip(M,Ratio))]
M = sorted(M)
# Out:
# 322 {'LI num': [35, 46, 46, 46], 'dimension': [2, 3, 4, 5]}
# 222 {'LI num': [9, 9, 9, 9], 'dimension': [2, 3, 4, 5]}
# 422 {'LI num': [102, 161, 161, 161], 'dimension': [2, 3, 4, 5]}
# 622 {'LI num': [492, 937, 937, 937], 'dimension': [2, 3, 4, 5]}
# 522 {'LI num': [241, 426, 426, 426], 'dimension': [2, 3, 4, 5]}

# %%
fig = plt.figure(figsize=(17, 8))

plt.plot(M, Ratio, linewidth = 3, zorder=1)
plt.scatter(M, Ratio, zorder=2)

plt.xlabel('Number of measurements', fontsize=20)
plt.ylabel('Ratio of LI num', fontsize=20)
plt.tick_params(axis='both', labelsize=18)
plt.show()

# %% [markdown]
# # Classification in the M-2-3 Scenario

# %%
Ratio = []
M = []

for k in data.keys():
    if k[1:] == '23':
        print(k, data[k])
        M.append(int(k[0]))
        Ratio.append(data[k]['LI num'][1]/data[k]['LI num'][0])
        
Ratio = [r for _,r in sorted(zip(M,Ratio))]
M = sorted(M)

# %%
fig = plt.figure(figsize=(17, 8))

plt.plot(M, Ratio, linewidth = 3, zorder=1)
plt.scatter(M, Ratio, zorder=2)

plt.xlabel('Number of measurements', fontsize=20)
plt.ylabel('Ratio of LI num', fontsize=20)
plt.tick_params(axis='both', labelsize=18)
plt.show()
