# %%
from general_method.set_geom_prob import visibility, visibility_stability
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Q3 in Q2NPA1

# %%
X, etas = visibility_stability(eta_size=50)

# %%
etas
# Out:
# [1.141012133832329,
#  1.141012130390594,
#  1.1410121302711973,
#  1.1410121137887403,
#  1.1410121299490639,
#  1.1410121207070538,
#  1.1410121302180012,
#  1.1410121290460888,
#  1.1410121301490495,
#  1.1410121302086962,
#  1.141012129703541,
#  1.1410121302145324,
#  1.1410121293183533,
#  1.1410121298763982,
#  1.141012138542488,
#  1.1410121332892744,
#  1.1410121301981173,
#  1.1410121302136378,
#  1.1410121302177316,
#  1.1410121298659783,
#  1.1410121242947215,
#  1.141012130239793,
#  1.1410121305383698,
#  1.141012123041175,
#  1.1410121301862397,
#  1.1410121301608154,
#  1.1410121301829008,
#  1.1410121290911597,
#  1.14101212806829,
#  1.141012129537877,
#  1.1410121306611896,
#  1.141012130022045,
#  1.141012130184279,
#  1.1410121293933446,
#  1.1410121302535303,
#  1.14101213008367,
#  1.1410121182332453,
#  1.1410121293325795,
#  1.1410121225697656,
#  1.1410121304361778,
#  1.1410121302294012,
#  1.1410121302257588,
#  1.141012109884544,
#  1.1410121339603734,
# ...

# %%
plt.figure(figsize=(10,5))
ax = sns.distplot(etas, hist=True, kde=True,
             bins=int(len(etas)/10), color = 'darkblue',
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
ax.set(xlabel='Visibility')
# Out:
# [Text(0.5, 0, 'Visibility')]
